# %%
# !nvidia-smi
# Out:
# Tue Sep  8 09:45:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 450.51.05    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           Off  | 00000000:1B:00.0 Off |                  N/A |
# |100%   88C    P2   183W / 280W |  21920MiB / 24220MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !nnUNet_predict -h

# %%
# !ls OUTPUT_FOLDER/Tendon/3D_4ch/

# %% [markdown]
# # 2D prediction

# %%
# !sudo CUDA_VISIBLE_DEVICES=0 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task002_Tendon_4ch/imagesTs/ \
                                            -o OUTPUT_FOLDER/Tendon/3D_4ch/ \
                                            -t 2 \
                                            -m 3d_fullres \
                                            -f all

# %%
# 11:12 - 11:15
# !sudo CUDA_VISIBLE_DEVICES=0 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task002_Tendon_4ch/imagesTs/ \
                                            -o OUTPUT_FOLDER/Tendon/2D_4ch/ \
                                            -t 2 \
                                            -m 2d \
                                            -f all

# %%
#41 시작 끝
# !sudo CUDA_VISIBLE_DEVICES=5 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task001_Tendon_5ch/imagesTs/ \
                                            -o OUTPUT_FOLDER/Tendon/3D_5ch/ \
                                            -t 1 \
                                            -m 3d_fullres \
                                            -f all
# Out:
# Please cite the following paper when using nnUNet:
# Fabian Isensee, Paul F. Jäger, Simon A. A. Kohl, Jens Petersen, Klaus H. Maier-Hein "Automated Design of Deep Learning Methods for Biomedical Image Segmentation" arXiv preprint arXiv:1904.08128 (2020).
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /workspace/nnUnet/RESULTS_FOLDER/nnUNet/3d_fullres/Task001_Tendon_5ch/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 20 unique case ids, here are some examples: ['34682777' '1_image' '3_image' '2_image' '1_image' 'massiveRCT_F66'
#  '4_image' 'partial_02035506' 'small_4  02119076  F64'
#  'small_6  02111419  F57']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 20
# number of cases that still need to be predicted: 20
# emptying cuda cache
# loading parameters for folds, ['all']
# ...

# %%
# 52 start 
# !sudo CUDA_VISIBLE_DEVICES=0 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task001_Tendon_5ch/imagesTs/ \
                                            -o OUTPUT_FOLDER/Tendon/2D_5ch/ \
                                            -t 1 \
                                            -m 2d \
                                            -f all

# %%
# 34 ~ 
# !sudo CUDA_VISIBLE_DEVICES=0 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task003_Tendon_6ch/imagesTs/ \
                                            -o OUTPUT_FOLDER/Tendon/3D_6ch/ \
                                            -t 3 \
                                            -m 3d_fullres \
                                            -f all

# %%
# !sudo CUDA_VISIBLE_DEVICES=0 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task003_Tendon_6ch/imagesTs/ \
                                            -o OUTPUT_FOLDER/Tendon/2D_6ch/ \
                                            -t 3 \
                                            -m 2d \
                                            -f all

# %%
# !sudo CUDA_VISIBLE_DEVICES=0 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task004_Tendon_1ch/imagesTs/ \
                                            -o OUTPUT_FOLDER/Tendon/3D_1ch/ \
                                            -t 4 \
                                            -m 3d_fullres \
                                            -f all

# %%
# !sudo CUDA_VISIBLE_DEVICES=0 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task004_Tendon_1ch/imagesTs/ \
                                            -o OUTPUT_FOLDER/Tendon/2D_1ch/ \
                                            -t 4 \
                                            -m 2d \
                                            -f all

# %% [markdown]
# # 3D prediction

# %%
# !CUDA_VISIBLE_DEVICES=1 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task000_MY_DATASET/imagesTs/ -o OUTPUT_FOLDER/3D -t 0 -m 3d_fullres -f 0

# %%
# !sudo CUDA_VISIBLE_DEVICES=0 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task006_Pelvic/imagesTs/ \
                                            -o OUTPUT_FOLDER/Pelvic/2D/ \
                                            -t 6 \
                                            -m 2d \
                                            -f all
# Out:
# Please cite the following paper when using nnUNet:
# Fabian Isensee, Paul F. Jäger, Simon A. A. Kohl, Jens Petersen, Klaus H. Maier-Hein "Automated Design of Deep Learning Methods for Biomedical Image Segmentation" arXiv preprint arXiv:1904.08128 (2020).
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /workspace/nnUnet/RESULTS_FOLDER/nnUNet/2d/Task006_Pelvic/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 10 unique case ids, here are some examples: ['1152048755_1' '1152055173_1' '1152063043_0' '1152048755_0'
#  '1152055173_1' '1152049268_1' '1152055173_0' '1152055173_0'
#  '1152055173_1' '1152055172_0']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 10
# number of cases that still need to be predicted: 10
# emptying cuda cache
# loading parameters for folds, ['all']
# ...

# %%
# !sudo CUDA_VISIBLE_DEVICES=2 nnUNet_predict -i nnUNet_base/nnUNet_raw_data/Task008_Pancreas/imagesTs/ \
                                            -o OUTPUT_FOLDER/Pancreas/2D/ \
                                            -t 8 \
                                            -m 2d \
                                            -f all
# Out:
# Please cite the following paper when using nnUNet:
# Fabian Isensee, Paul F. Jäger, Simon A. A. Kohl, Jens Petersen, Klaus H. Maier-Hein "Automated Design of Deep Learning Methods for Biomedical Image Segmentation" arXiv preprint arXiv:1904.08128 (2020).
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /workspace/nnUnet/RESULTS_FOLDER/nnUNet/2d/Task008_Pancreas/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 10 unique case ids, here are some examples: ['2014_180210_cancer_27237991_image' '2011_180130_cyst_11102393_image'
#  '2011_180130_cyst_0008_42518024_image'
#  '2014_180210_cancer_27237991_image' '2014_180210_cancer_27769676_image'
#  '2011_180130_cyst_21644902_image' '2014_180210_cancer_27752128_image'
#  '2014_180210_cancer_28082505_image' '2011_180130_cyst_21644902_image'
#  '2010_180130_cyst_41079379_image']
# ...
